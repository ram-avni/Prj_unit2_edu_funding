# %%
import requests
from bs4 import BeautifulSoup

# %%
data = requests.get('https://www.governing.com/gov-data/high-school-graduation-rates-by-state.html')
html = BeautifulSoup(data.content,'html.parser')
html_page = list(html.children)[3]
body = html_page.find_all('body')
tables = body[0].find_all('table')
main_table = tables[0]
main_table = list(main_table)
main_table[3].get_text().split('\n')
# Out:
# ['',
#  '',
#  '\xa0United States',
#  '83.2%',
#  '82.3%',
#  '81.4%',
#  '80%',
#  '79%',
#  '',
#  '',
#  'Alabama',
#  '89.3%',
#  '86.3%',
#  '80.0%',
#  '75%',
#  '72%',
#  '',
#  '',
#  'Alaska',
#  '75.6%',
#  '71.1%',
#  '71.8%',
#  '70%',
#  '68%',
#  '',
#  '',
#  'Arizona',
#  '77.4%',
#  '75.7%',
#  '75.1%',
#  '76%',
#  '78%',
#  '',
#  '',
#  'Arkansas',
#  '84.9%',
#  '86.9%',
#  '84.9%',
#  '84%',
#  '81%',
#  '',
#  '',
#  'California',
#  '82.0%',
#  '81.0%',
#  '80.4%',
#  '79%',
#  '76%',
#  '',
#  '',
#  'Colorado',
#  '77.3%',
#  '77.3%',
#  '76.9%',
#  '75%',
#  '74%',
#  '',
#  '',
#  'Connecticut',
#  '87.2%',
#  '87.0%',
#  '85.5%',
#  '85%',
#  '83%',
#  '',
#  '',
#  'Delaware',
#  '85.6%',
#  '87.0%',
#  '80.4%',
#  '80%',
#  '78%',
#  '',
#  '',
#  'District of Columbia',
#  '68.5%',
#  '61.4%',
#  '62.3%',
#  '59%',
#  '59%',
#  '',
#  '',
#  'Florida',
#  '77.9%',
#  '76.1%',
#  '75.6%',
#  '75%',
#  '71%',
#  '',
#  '',
#  'Georgia',
#  '78.8%',
#  '72.5%',
#  '71.7%',
#  '70%',
#  '67%',
#  '',
#  '',
#  'Hawaii',
#  '81.6%',
#  '81.8%',
#  '82.4%',
#  '81%',
#  '80%',
#  '',
#  '',
#  'Idaho',
#  '78.9%',
#  '77.3%',
#  '-',
#  '-',
#  '-',
#  '',
#  '',
#  'Illinois',
#  '85.6%',
#  '86.0%',
#  '83.2%',
#  '82%',
#  '84%',
#  '',
#  '',
#  'Indiana',
#  '87.1%',
#  '87.9%',
#  '87.0%',
#  '86%',
#  '86%',
#  '',
#  '',
#  'Iowa',
#  '90.8%',
#  '90.5%',
#  '89.7%',
#  '89%',
#  '88%',
#  '',
#  '',
#  'Kansas',
#  '85.7%',
#  '85.7%',
#  '85.7%',
#  '85%',
#  '83%',
#  '',
#  '',
#  'Kentucky',
#  '88.0%',
#  '87.5%',
#  '86.1%',
#  '-',
#  '-',
#  '',
#  '',
#  'Louisiana',
#  '77.5%',
#  '74.6%',
#  '73.5%',
#  '72%',
#  '71%',
#  '',
#  '',
#  'Maine',
#  '87.5%',
#  '86.5%',
#  '86.4%',
#  '85%',
#  '84%',
#  '',
#  '',
#  'Maryland',
#  '87.0%',
#  '86.4%',
#  '85.0%',
#  '84%',
#  '83%',
#  '',
#  '',
#  'Massachusetts',
#  '87.3%',
#  '86.1%',
#  '85.0%',
#  '85%',
#  '83%',
#  '',
#  '',
#  'Michigan',
#  '79.8%',
#  '78.6%',
#  '77.0%',
#  '76%',
#  '74%',
#  '',
#  '',
#  'Minnesota',
#  '81.9%',
#  '81.2%',
#  '79.8%',
#  '78%',
#  '77%',
#  '',
#  '',
#  'Mississippi',
#  '75.4%',
#  '77.6%',
#  '75.5%',
#  '75%',
#  '75%',
#  '',
#  '',
#  'Missouri',
#  '87.8%',
#  '87.3%',
#  '85.7%',
#  '84%',
#  '81%',
#  '',
#  '',
#  'Montana',
#  '86.0%',
#  '85.4%',
#  '84.4%',
#  '84%',
#  '82%',
#  '',
#  '',
#  'Nebraska',
#  '88.9%',
#  '89.7%',
#  '88.5%',
#  '88%',
#  '86%',
#  '',
#  '',
#  'Nevada',
#  '71.3%',
#  '70.0%',
#  '70.7%',
#  '63%',
#  '62%',
#  '',
#  '',
#  'New Hampshire',
#  '88.1%',
#  '88.1%',
#  '87.3%',
#  '86%',
#  '86%',
#  '',
#  '',
#  'New Jersey',
#  '89.7%',
#  '88.6%',
#  '87.5%',
#  '86%',
#  '83%',
#  '',
#  '',
#  'New Mexico',
#  '68.6%',
#  '68.5%',
#  '70.3%',
#  '70%',
#  '63%',
#  '',
#  '',
#  'New York',
#  '79.2%',
#  '77.8%',
#  '76.8%',
#  '77%',
#  '77%',
#  '',
#  '',
#  'North Carolina',
#  '85.6%',
#  '83.9%',
#  '82.5%',
#  '80%',
#  '78%',
#  '',
#  '',
#  'North Dakota',
#  '86.6%',
#  '87.2%',
#  '87.5%',
#  '87%',
#  '86%',
#  '',
#  '',
#  'Ohio',
#  '80.7%',
#  '81.8%',
#  '82.2%',
#  '81%',
#  '80%',
#  '',
#  '',
#  'Oklahoma',
#  '82.5%',
#  '82.7%',
#  '84.8%',
#  '-',
#  '-',
#  '',
#  '',
#  'Oregon',
#  '73.8%',
#  '72.0%',
#  '68.7%',
#  '68%',
#  '68%',
#  '',
#  '',
#  'Pennsylvania',
#  '84.8%',
#  '85.3%',
#  '85.5%',
#  '84%',
#  '83%',
#  '',
#  '',
#  'Rhode Island',
#  '83.2%',
#  '80.8%',
#  '79.7%',
#  '77%',
#  '77%',
#  '',
#  '',
#  'South Carolina',
#  '80.3%',
#  '80.1%',
#  '77.6%',
#  '75%',
#  '74%',
#  '',
#  '',
#  'South Dakota',
#  '83.9%',
#  '82.7%',
#  '82.7%',
#  '83%',
#  '83%',
#  '',
#  '',
#  'Tennessee',
#  '87.9%',
#  '87.2%',
#  '86.3%',
#  '87%',
#  '86%',
#  '',
#  '',
#  'Texas',
#  '89.0%',
#  '88.3%',
#  '88.0%',
#  '88%',
#  '86%',
#  '',
#  '',
#  'Utah',
#  '84.8%',
#  '83.9%',
#  '83.0%',
#  '80%',
#  '76%',
#  '',
#  '',
#  'Vermont',
#  '87.7%',
#  '87.8%',
#  '86.6%',
#  '88%',
#  '87%',
#  '',
#  '',
#  'Virginia',
#  '85.7%',
#  '85.3%',
#  '84.5%',
#  '83%',
#  '82%',
#  '',
#  '',
#  'Washington',
#  '78.2%',
#  '78.2%',
#  '76.4%',
#  '77%',
#  '76%',
#  '',
#  '',
#  'West Virginia',
#  '86.5%',
#  '84.5%',
#  '81.4%',
#  '79%',
#  '78%',
#  '',
#  '',
#  'Wisconsin',
#  '88.4%',
#  '88.6%',
#  '88.0%',
#  '88%',
#  '87%',
#  '',
#  '',
#  'Wyoming',
#  '79.3%',
#  '78.6%',
#  '77.0%',
#  '79%',
#  '80%',
#  '',
#  '']

# %%
data = []
for x in main_table[3].get_text().split('\n'):
    if x == '':
        continue
    else:
        data.append(x)
        
data
# Out:
# ['\xa0United States',
#  '83.2%',
#  '82.3%',
#  '81.4%',
#  '80%',
#  '79%',
#  'Alabama',
#  '89.3%',
#  '86.3%',
#  '80.0%',
#  '75%',
#  '72%',
#  'Alaska',
#  '75.6%',
#  '71.1%',
#  '71.8%',
#  '70%',
#  '68%',
#  'Arizona',
#  '77.4%',
#  '75.7%',
#  '75.1%',
#  '76%',
#  '78%',
#  'Arkansas',
#  '84.9%',
#  '86.9%',
#  '84.9%',
#  '84%',
#  '81%',
#  'California',
#  '82.0%',
#  '81.0%',
#  '80.4%',
#  '79%',
#  '76%',
#  'Colorado',
#  '77.3%',
#  '77.3%',
#  '76.9%',
#  '75%',
#  '74%',
#  'Connecticut',
#  '87.2%',
#  '87.0%',
#  '85.5%',
#  '85%',
#  '83%',
#  'Delaware',
#  '85.6%',
#  '87.0%',
#  '80.4%',
#  '80%',
#  '78%',
#  'District of Columbia',
#  '68.5%',
#  '61.4%',
#  '62.3%',
#  '59%',
#  '59%',
#  'Florida',
#  '77.9%',
#  '76.1%',
#  '75.6%',
#  '75%',
#  '71%',
#  'Georgia',
#  '78.8%',
#  '72.5%',
#  '71.7%',
#  '70%',
#  '67%',
#  'Hawaii',
#  '81.6%',
#  '81.8%',
#  '82.4%',
#  '81%',
#  '80%',
#  'Idaho',
#  '78.9%',
#  '77.3%',
#  '-',
#  '-',
#  '-',
#  'Illinois',
#  '85.6%',
#  '86.0%',
#  '83.2%',
#  '82%',
#  '84%',
#  'Indiana',
#  '87.1%',
#  '87.9%',
#  '87.0%',
#  '86%',
#  '86%',
#  'Iowa',
#  '90.8%',
#  '90.5%',
#  '89.7%',
#  '89%',
#  '88%',
#  'Kansas',
#  '85.7%',
#  '85.7%',
#  '85.7%',
#  '85%',
#  '83%',
#  'Kentucky',
#  '88.0%',
#  '87.5%',
#  '86.1%',
#  '-',
#  '-',
#  'Louisiana',
#  '77.5%',
#  '74.6%',
#  '73.5%',
#  '72%',
#  '71%',
#  'Maine',
#  '87.5%',
#  '86.5%',
#  '86.4%',
#  '85%',
#  '84%',
#  'Maryland',
#  '87.0%',
#  '86.4%',
#  '85.0%',
#  '84%',
#  '83%',
#  'Massachusetts',
#  '87.3%',
#  '86.1%',
#  '85.0%',
#  '85%',
#  '83%',
#  'Michigan',
#  '79.8%',
#  '78.6%',
#  '77.0%',
#  '76%',
#  '74%',
#  'Minnesota',
#  '81.9%',
#  '81.2%',
#  '79.8%',
#  '78%',
#  '77%',
#  'Mississippi',
#  '75.4%',
#  '77.6%',
#  '75.5%',
#  '75%',
#  '75%',
#  'Missouri',
#  '87.8%',
#  '87.3%',
#  '85.7%',
#  '84%',
#  '81%',
#  'Montana',
#  '86.0%',
#  '85.4%',
#  '84.4%',
#  '84%',
#  '82%',
#  'Nebraska',
#  '88.9%',
#  '89.7%',
#  '88.5%',
#  '88%',
#  '86%',
#  'Nevada',
#  '71.3%',
#  '70.0%',
#  '70.7%',
#  '63%',
#  '62%',
#  'New Hampshire',
#  '88.1%',
#  '88.1%',
#  '87.3%',
#  '86%',
#  '86%',
#  'New Jersey',
#  '89.7%',
#  '88.6%',
#  '87.5%',
#  '86%',
#  '83%',
#  'New Mexico',
#  '68.6%',
#  '68.5%',
#  '70.3%',
#  '70%',
#  '63%',
#  'New York',
#  '79.2%',
#  '77.8%',
#  '76.8%',
#  '77%',
#  '77%',
#  'North Carolina',
#  '85.6%',
#  '83.9%',
#  '82.5%',
#  '80%',
#  '78%',
#  'North Dakota',
#  '86.6%',
#  '87.2%',
#  '87.5%',
#  '87%',
#  '86%',
#  'Ohio',
#  '80.7%',
#  '81.8%',
#  '82.2%',
#  '81%',
#  '80%',
#  'Oklahoma',
#  '82.5%',
#  '82.7%',
#  '84.8%',
#  '-',
#  '-',
#  'Oregon',
#  '73.8%',
#  '72.0%',
#  '68.7%',
#  '68%',
#  '68%',
#  'Pennsylvania',
#  '84.8%',
#  '85.3%',
#  '85.5%',
#  '84%',
#  '83%',
#  'Rhode Island',
#  '83.2%',
#  '80.8%',
#  '79.7%',
#  '77%',
#  '77%',
#  'South Carolina',
#  '80.3%',
#  '80.1%',
#  '77.6%',
#  '75%',
#  '74%',
#  'South Dakota',
#  '83.9%',
#  '82.7%',
#  '82.7%',
#  '83%',
#  '83%',
#  'Tennessee',
#  '87.9%',
#  '87.2%',
#  '86.3%',
#  '87%',
#  '86%',
#  'Texas',
#  '89.0%',
#  '88.3%',
#  '88.0%',
#  '88%',
#  '86%',
#  'Utah',
#  '84.8%',
#  '83.9%',
#  '83.0%',
#  '80%',
#  '76%',
#  'Vermont',
#  '87.7%',
#  '87.8%',
#  '86.6%',
#  '88%',
#  '87%',
#  'Virginia',
#  '85.7%',
#  '85.3%',
#  '84.5%',
#  '83%',
#  '82%',
#  'Washington',
#  '78.2%',
#  '78.2%',
#  '76.4%',
#  '77%',
#  '76%',
#  'West Virginia',
#  '86.5%',
#  '84.5%',
#  '81.4%',
#  '79%',
#  '78%',
#  'Wisconsin',
#  '88.4%',
#  '88.6%',
#  '88.0%',
#  '88%',
#  '87%',
#  'Wyoming',
#  '79.3%',
#  '78.6%',
#  '77.0%',
#  '79%',
#  '80%']

# %%
del data[0:6]
data
# Out:
# ['Alabama',
#  '89.3%',
#  '86.3%',
#  '80.0%',
#  '75%',
#  '72%',
#  'Alaska',
#  '75.6%',
#  '71.1%',
#  '71.8%',
#  '70%',
#  '68%',
#  'Arizona',
#  '77.4%',
#  '75.7%',
#  '75.1%',
#  '76%',
#  '78%',
#  'Arkansas',
#  '84.9%',
#  '86.9%',
#  '84.9%',
#  '84%',
#  '81%',
#  'California',
#  '82.0%',
#  '81.0%',
#  '80.4%',
#  '79%',
#  '76%',
#  'Colorado',
#  '77.3%',
#  '77.3%',
#  '76.9%',
#  '75%',
#  '74%',
#  'Connecticut',
#  '87.2%',
#  '87.0%',
#  '85.5%',
#  '85%',
#  '83%',
#  'Delaware',
#  '85.6%',
#  '87.0%',
#  '80.4%',
#  '80%',
#  '78%',
#  'District of Columbia',
#  '68.5%',
#  '61.4%',
#  '62.3%',
#  '59%',
#  '59%',
#  'Florida',
#  '77.9%',
#  '76.1%',
#  '75.6%',
#  '75%',
#  '71%',
#  'Georgia',
#  '78.8%',
#  '72.5%',
#  '71.7%',
#  '70%',
#  '67%',
#  'Hawaii',
#  '81.6%',
#  '81.8%',
#  '82.4%',
#  '81%',
#  '80%',
#  'Idaho',
#  '78.9%',
#  '77.3%',
#  '-',
#  '-',
#  '-',
#  'Illinois',
#  '85.6%',
#  '86.0%',
#  '83.2%',
#  '82%',
#  '84%',
#  'Indiana',
#  '87.1%',
#  '87.9%',
#  '87.0%',
#  '86%',
#  '86%',
#  'Iowa',
#  '90.8%',
#  '90.5%',
#  '89.7%',
#  '89%',
#  '88%',
#  'Kansas',
#  '85.7%',
#  '85.7%',
#  '85.7%',
#  '85%',
#  '83%',
#  'Kentucky',
#  '88.0%',
#  '87.5%',
#  '86.1%',
#  '-',
#  '-',
#  'Louisiana',
#  '77.5%',
#  '74.6%',
#  '73.5%',
#  '72%',
#  '71%',
#  'Maine',
#  '87.5%',
#  '86.5%',
#  '86.4%',
#  '85%',
#  '84%',
#  'Maryland',
#  '87.0%',
#  '86.4%',
#  '85.0%',
#  '84%',
#  '83%',
#  'Massachusetts',
#  '87.3%',
#  '86.1%',
#  '85.0%',
#  '85%',
#  '83%',
#  'Michigan',
#  '79.8%',
#  '78.6%',
#  '77.0%',
#  '76%',
#  '74%',
#  'Minnesota',
#  '81.9%',
#  '81.2%',
#  '79.8%',
#  '78%',
#  '77%',
#  'Mississippi',
#  '75.4%',
#  '77.6%',
#  '75.5%',
#  '75%',
#  '75%',
#  'Missouri',
#  '87.8%',
#  '87.3%',
#  '85.7%',
#  '84%',
#  '81%',
#  'Montana',
#  '86.0%',
#  '85.4%',
#  '84.4%',
#  '84%',
#  '82%',
#  'Nebraska',
#  '88.9%',
#  '89.7%',
#  '88.5%',
#  '88%',
#  '86%',
#  'Nevada',
#  '71.3%',
#  '70.0%',
#  '70.7%',
#  '63%',
#  '62%',
#  'New Hampshire',
#  '88.1%',
#  '88.1%',
#  '87.3%',
#  '86%',
#  '86%',
#  'New Jersey',
#  '89.7%',
#  '88.6%',
#  '87.5%',
#  '86%',
#  '83%',
#  'New Mexico',
#  '68.6%',
#  '68.5%',
#  '70.3%',
#  '70%',
#  '63%',
#  'New York',
#  '79.2%',
#  '77.8%',
#  '76.8%',
#  '77%',
#  '77%',
#  'North Carolina',
#  '85.6%',
#  '83.9%',
#  '82.5%',
#  '80%',
#  '78%',
#  'North Dakota',
#  '86.6%',
#  '87.2%',
#  '87.5%',
#  '87%',
#  '86%',
#  'Ohio',
#  '80.7%',
#  '81.8%',
#  '82.2%',
#  '81%',
#  '80%',
#  'Oklahoma',
#  '82.5%',
#  '82.7%',
#  '84.8%',
#  '-',
#  '-',
#  'Oregon',
#  '73.8%',
#  '72.0%',
#  '68.7%',
#  '68%',
#  '68%',
#  'Pennsylvania',
#  '84.8%',
#  '85.3%',
#  '85.5%',
#  '84%',
#  '83%',
#  'Rhode Island',
#  '83.2%',
#  '80.8%',
#  '79.7%',
#  '77%',
#  '77%',
#  'South Carolina',
#  '80.3%',
#  '80.1%',
#  '77.6%',
#  '75%',
#  '74%',
#  'South Dakota',
#  '83.9%',
#  '82.7%',
#  '82.7%',
#  '83%',
#  '83%',
#  'Tennessee',
#  '87.9%',
#  '87.2%',
#  '86.3%',
#  '87%',
#  '86%',
#  'Texas',
#  '89.0%',
#  '88.3%',
#  '88.0%',
#  '88%',
#  '86%',
#  'Utah',
#  '84.8%',
#  '83.9%',
#  '83.0%',
#  '80%',
#  '76%',
#  'Vermont',
#  '87.7%',
#  '87.8%',
#  '86.6%',
#  '88%',
#  '87%',
#  'Virginia',
#  '85.7%',
#  '85.3%',
#  '84.5%',
#  '83%',
#  '82%',
#  'Washington',
#  '78.2%',
#  '78.2%',
#  '76.4%',
#  '77%',
#  '76%',
#  'West Virginia',
#  '86.5%',
#  '84.5%',
#  '81.4%',
#  '79%',
#  '78%',
#  'Wisconsin',
#  '88.4%',
#  '88.6%',
#  '88.0%',
#  '88%',
#  '87%',
#  'Wyoming',
#  '79.3%',
#  '78.6%',
#  '77.0%',
#  '79%',
#  '80%']

# %%
for x in range(0, len(data)/6):
    for i in range(0,5):
        grad_dict = {data[i*x]: data[i*x+1],
                              data[i+2],
                              data[i+3],
                              data[i+4],
                              data[i+5]}
        list_grad_dict.append(grad_dict)
# Out:
#   File "<ipython-input-8-405034181c80>", line 4
#     data[i+2],
#              ^
# SyntaxError: invalid syntax

# %%
def add_grad():
    if df['STATE'] == df_grad['STATE'] & df['YEAR'] == df_grad['YEAR']

    
df.apply(add_grad)
